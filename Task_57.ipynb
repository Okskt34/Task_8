# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image, ImageEnhance, ImageOps
import matplotlib.pyplot as plt

# %%
image_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/cat.jpg'
image = Image.open(image_path)

# %%
plt.imshow(image)
plt.axis('off')  
plt.show()

# %%
def display_image(image_path):
    image = Image.open(image_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
def save_image(image, output_path):
    image.save(output_path)

# %%
image = Image.open('C:/Users/ASUS/OneDrive/Рабочий стол/cat.jpg')
save_image(image, 'output_image.jpg')

# %%
def change_contrast_brightness(image, contrast_factor, brightness_factor):
    enhancer = ImageEnhance.Brightness(image)
    image = enhancer.enhance(brightness_factor)
    
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(contrast_factor)
    
    return image

# %%
def change_brightness(image, brightness_factor):
    enhancer = ImageEnhance.Brightness(image)
    image = enhancer.enhance(brightness_factor)
    return image

# %%
def change_saturation(image, saturation_factor):
    image = Image.fromarray(np.array(image)[:, :, ::-1])  # Convert PIL image to RGB numpy array
    hsv_image = color.rgb2hsv(image)
    hsv_image[:, :, 1] *= saturation_factor  # Multiply saturation channel by the factor
    hsv_image[:, :, 1] = np.clip(hsv_image[:, :, 1], 0, 1)  # Clip values to [0, 1]
    image = color.hsv2rgb(hsv_image)  # Convert back to RGB
    return Image.fromarray((image * 255).astype(np.uint8))

# %%
def resize_image(image, new_width, new_height):
    resized_image = image.resize((new_width, new_height), Image.ANTIALIAS)
    return resized_image

# %%
def crop_image(image, left, upper, right, lower):
    cropped_image = image.crop((left, upper, right, lower))
    return cropped_image

# %%
def rotate_image(image, angle):
    rotated_image = image.rotate(angle)
    return rotated_image
