# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\asus\anaconda3\anakonda\lib\site-packages (9.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\anakonda\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\anakonda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
image_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/cat.jpg'
image = Image.open(image_path)

# %%
plt.imshow(image)
plt.axis('off')  
plt.show()

# %%
image_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/cat.jpg'
image = Image.open(image_path)

# %%
r, g, b = image.split()

# %%
plt.figure(figsize=(10, 4))

# %%
plt.subplot(131)
plt.imshow(r, cmap='Reds')
plt.title('Red Channel')
plt.axis('off')
# Out:
# (-0.5, 458.5, 389.5, -0.5)

# %%
plt.subplot(132)
plt.imshow(g, cmap='Greens')
plt.title('Green Channel')
plt.axis('off')
# Out:
# (-0.5, 458.5, 389.5, -0.5)

# %%
plt.subplot(133)
plt.imshow(b, cmap='Blues')
plt.title('Blue Channel')
plt.axis('off')
# Out:
# (-0.5, 458.5, 389.5, -0.5)

# %%
plt.tight_layout()
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt
import colorsys

# %%
image_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/cat.jpg'
image = Image.open(image_path)

# %%
image_hsv = image.convert('HSV')

# %%
h, s, v = image_hsv.split()

# %%
plt.figure(figsize=(10, 4))

# %%
plt.subplot(131)
plt.imshow(h, cmap='hsv')
plt.title('Hue Channel')
plt.axis('off')
# Out:
# (-0.5, 458.5, 389.5, -0.5)

# %%
plt.subplot(132)
plt.imshow(s, cmap='gray')
plt.title('Saturation Channel')
plt.axis('off')
# Out:
# (-0.5, 458.5, 389.5, -0.5)
